# %%
# !pip install datasets
# !pip install catboost
import pandas as pd
from sklearn.model_selection import train_test_split
import re
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import pandas as pd
# import nltk
# from nltk.util import ngrams
from sklearn.feature_extraction.text import TfidfVectorizer
import gc
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from catboost import CatBoostClassifier
from sklearn.ensemble import VotingClassifier
# from datasets import Dataset
# from transformers import PreTrainedTokenizerFast
from tqdm import tqdm
import torch
# from tokenizers import (
#     decoders,
#     models,
#     normalizers,
#     pre_tokenizers,
#     processors,
#     trainers,
#     Tokenizer,
# )
import numpy as np
from scipy.sparse import save_npz, load_npz

# %%
LOWERCASE = True
VOCAB_SIZE = 32000

# %%
train = pd.read_csv("data/train_preprocessed_fill_missing.csv")
test = pd.read_csv("data/test_preprocessed_fill_missing.csv")

# %%
# train['text'] = train['title'].astype(str) + " " + train['content'].astype(str)
# test['text'] = test['title'].astype(str) + " " + test['content'].astype(str)

# %%
# df = pd.concat([train['text'], test['text']], axis=0)

# %%
# raw_tokenizer = Tokenizer(models.BPE(unk_token="[UNK]"))
# raw_tokenizer.normalizer = normalizers.Sequence([normalizers.NFKD()] + [normalizers.Lowercase()] if LOWERCASE else [])
# raw_tokenizer.pre_tokenizer = pre_tokenizers.Whitespace()

# special_tokens = ["[UNK]", "[PAD]", "[CLS]", "[SEP]", "[MASK]", "[BOS]"]
# trainer = trainers.BpeTrainer(vocab_size=VOCAB_SIZE, special_tokens=special_tokens)

# dataset = Dataset.from_pandas(test[['text']])

# def train_corp_iter():
#     for i in range(0, len(dataset), 1000):
#         yield dataset[i: i + 1000]["text"]

# raw_tokenizer.train_from_iterator(train_corp_iter(), trainer=trainer)

# tokenizer = PreTrainedTokenizerFast(
#     tokenizer_object=raw_tokenizer,
#     unk_token="[UNK]",
#     pad_token="[PAD]",
#     cls_token="[CLS]",
#     sep_token="[SEP]",
#     mask_token="[MASK]",
#     bos_token="[BOS]"
# )

# tokenized_texts_test = [tokenizer.tokenize(text) for text in tqdm(test['text'].tolist())]
# tokenized_texts_train = [tokenizer.tokenize(text) for text in tqdm(train['text'].tolist())]

# %%
# vectorizer = TfidfVectorizer(ngram_range=(3, 5),tokenizer=lambda x: re.findall(r'[^\W]+', x),token_pattern=None,strip_accents='unicode',)
# vectorizer = vectorizer.fit([" ".join(text) for text in tokenized_texts_train])
X = load_npz('data/train_tfidf_embeddings.npz')

# %%
X_train, X_test, y_train, y_test = train_test_split(X[:train.shape[0]], train.target, test_size=0.2, random_state=42)

# %%
lr = LogisticRegression(multi_class="multinomial", solver="lbfgs", random_state=42)

sgd_model = SGDClassifier(max_iter=4096, tol=1e-3, loss="modified_huber", random_state=42)
sgd_model2 = SGDClassifier(max_iter=4096, tol=1e-4, loss="modified_huber", class_weight="balanced", random_state=42)
sgd_model3 = SGDClassifier(max_iter=4096, tol=5e-4, loss="modified_huber", early_stopping=True, random_state=42)

mnb_model = MultinomialNB(alpha=0.02)
mnb_model2 = MultinomialNB(alpha=0.1)
mnb_model3 = MultinomialNB(alpha=0.2)

catboost_model = CatBoostClassifier(
    iterations=512, learning_rate=0.1, depth=3,
    loss_function='MultiClass', eval_metric='MultiClass', random_state=42
)

# %%
ensemble = VotingClassifier(estimators=[
        ('lr', lr),
        ('sgd', sgd_model),
        ('sgd2', sgd_model2),
        ('sgd3', sgd_model3),
        ('cat', catboost_model),
        ('mnb', mnb_model),
        ('mnb2', mnb_model2),
        ('mnb3', mnb_model3),
    ],voting='soft')
ensemble.fit(X_train, y_train)
# Out:
# d:\cs\envs\dpl\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0:	learn: 1.5653862	total: 790ms	remaining: 6m 43s
# 1:	learn: 1.5301618	total: 1.04s	remaining: 4m 24s
# 2:	learn: 1.5016965	total: 1.27s	remaining: 3m 35s
# 3:	learn: 1.4778635	total: 1.47s	remaining: 3m 6s
# 4:	learn: 1.4586312	total: 1.65s	remaining: 2m 47s
# 5:	learn: 1.4433088	total: 1.83s	remaining: 2m 34s
# 6:	learn: 1.4288360	total: 2.04s	remaining: 2m 27s
# 7:	learn: 1.4172342	total: 2.23s	remaining: 2m 20s
# 8:	learn: 1.4040066	total: 2.4s	remaining: 2m 14s
# 9:	learn: 1.3934772	total: 2.65s	remaining: 2m 12s
# 10:	learn: 1.3840620	total: 2.83s	remaining: 2m 8s
# 11:	learn: 1.3751423	total: 3.01s	remaining: 2m 5s
# 12:	learn: 1.3685903	total: 3.2s	remaining: 2m 2s
# 13:	learn: 1.3604932	total: 3.38s	remaining: 2m
# 14:	learn: 1.3543015	total: 3.56s	remaining: 1m 58s
# 15:	learn: 1.3483147	total: 3.75s	remaining: 1m 56s
# 16:	learn: 1.3423593	total: 3.94s	remaining: 1m 54s
# 17:	learn: 1.3380336	total: 4.14s	remaining: 1m 53s
# 18:	learn: 1.3345007	total: 4.32s	remaining: 1m 51s
# 19:	learn: 1.3301645	total: 4.5s	remaining: 1m 50s
# 20:	learn: 1.3266886	total: 4.68s	remaining: 1m 49s
# 21:	learn: 1.3218459	total: 4.89s	remaining: 1m 48s
# 22:	learn: 1.3192500	total: 5.1s	remaining: 1m 48s
# 23:	learn: 1.3142943	total: 5.3s	remaining: 1m 47s
# 24:	learn: 1.3100874	total: 5.5s	remaining: 1m 47s
# 25:	learn: 1.3069331	total: 5.7s	remaining: 1m 46s
# 26:	learn: 1.3027346	total: 5.9s	remaining: 1m 45s
# 27:	learn: 1.3001702	total: 6.09s	remaining: 1m 45s
# 28:	learn: 1.2975619	total: 6.28s	remaining: 1m 44s
# 29:	learn: 1.2950493	total: 6.47s	remaining: 1m 43s
# 30:	learn: 1.2928556	total: 6.66s	remaining: 1m 43s
# 31:	learn: 1.2904725	total: 6.87s	remaining: 1m 43s
# 32:	learn: 1.2882720	total: 7.06s	remaining: 1m 42s
# 33:	learn: 1.2859036	total: 7.25s	remaining: 1m 41s
# 34:	learn: 1.2829068	total: 7.44s	remaining: 1m 41s
# 35:	learn: 1.2790555	total: 7.68s	remaining: 1m 41s
# 36:	learn: 1.2766279	total: 7.88s	remaining: 1m 41s
# 37:	learn: 1.2742630	total: 8.09s	remaining: 1m 40s
# 491:	learn: 0.9582498	total: 1m 47s	remaining: 4.35s
# 492:	learn: 0.9581069	total: 1m 47s	remaining: 4.13s
# 493:	learn: 0.9579408	total: 1m 47s	remaining: 3.92s
# 494:	learn: 0.9577134	total: 1m 47s	remaining: 3.7s
# 495:	learn: 0.9575291	total: 1m 47s	remaining: 3.48s
# 496:	learn: 0.9572575	total: 1m 48s	remaining: 3.27s
# 497:	learn: 0.9569734	total: 1m 48s	remaining: 3.05s
# 498:	learn: 0.9567064	total: 1m 48s	remaining: 2.83s
# 499:	learn: 0.9564570	total: 1m 48s	remaining: 2.61s
# 500:	learn: 0.9561603	total: 1m 49s	remaining: 2.4s
# 501:	learn: 0.9558778	total: 1m 49s	remaining: 2.18s
# 502:	learn: 0.9556095	total: 1m 49s	remaining: 1.96s
# 503:	learn: 0.9553300	total: 1m 49s	remaining: 1.74s
# 504:	learn: 0.9550627	total: 1m 49s	remaining: 1.52s
# 505:	learn: 0.9546797	total: 1m 50s	remaining: 1.31s
# 506:	learn: 0.9542696	total: 1m 50s	remaining: 1.09s
# 507:	learn: 0.9540288	total: 1m 50s	remaining: 871ms
# 508:	learn: 0.9538344	total: 1m 50s	remaining: 653ms
# 509:	learn: 0.9536090	total: 1m 51s	remaining: 435ms
# 510:	learn: 0.9533791	total: 1m 51s	remaining: 218ms
# 511:	learn: 0.9531296	total: 1m 51s	remaining: 0us
# VotingClassifier(estimators=[('lr',
#                               LogisticRegression(multi_class='multinomial',
#                                                  random_state=42)),
#                              ('sgd',
#                               SGDClassifier(loss='modified_huber',
#                                             max_iter=4096, random_state=42)),
#                              ('sgd2',
#                               SGDClassifier(class_weight='balanced',
#                                             loss='modified_huber',
#                                             max_iter=4096, random_state=42,
#                                             tol=0.0001)),
#                              ('sgd3',
#                               SGDClassifier(early_stopping=True,
#                                             loss='modified_huber',
#                                             max_iter=4096, random_state=42,
#                                             tol=0.0005)),
#                              ('cat',
#                               <catboost.core.CatBoostClassifier object at 0x000001D91DE63940>),
#                              ('mnb', MultinomialNB(alpha=0.02)),
#                              ('mnb2', MultinomialNB(alpha=0.1)),
#                              ('mnb3', MultinomialNB(alpha=0.2))],
#                  voting='soft')

# %%
from sklearn.metrics import accuracy_score
preds_test_classes = ensemble.predict(X_test)

accuracy = accuracy_score(y_test, preds_test_classes)

print(f'Accuracy on the test set: {accuracy:.4f}')
# Out:
# Accuracy on the test set: 0.6441

# %%
test_X = load_npz('data/test_tfidf_embeddings.npz')

# %%
preds_test = ensemble.predict(test_X)

# %%
preds_test
# Out:
# array(['depression', 'depression', 'depression', ...,
#        'relationship-and-family-issues', 'relationship-and-family-issues',
#        'anxiety'], dtype=object)

# %%
preds_test
# Out:
# array(['depression', 'relationship-and-family-issues', 'depression', ...,
#        'relationship-and-family-issues', 'relationship-and-family-issues',
#        'anxiety'], dtype=object)

# %%
pd.DataFrame({'id':test["id"],'target':preds_test}).sort_values(by="id").to_csv('data/submission_ensemble_tfidf.csv', index=False)
